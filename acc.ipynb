# %% [markdown]
# <a href="https://colab.research.google.com/github/Akasxh/HCAS_Accenture/blob/main/acc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file = pd.read_csv('output.csv')

# %%
file
# Out:
#       Age  Height(cm)  Weight(kg) Veg/Non-Veg Gender  Workout  Vegan  \
# 0      33         167         116         Veg      F     True   True
# 1      42         153          51     Non-veg      F    False  False
# 2      26         160          44         Veg      F    False   True
# 3      38         155         108         Veg      F     True  False
# 4      18         162         106     Non-veg      M     True  False
# ...   ...         ...         ...         ...    ...      ...    ...
# 9995   45         168          97     Non-veg      M     True  False
# 9996   46         170         115         Veg      M     True   True
# 9997   22         169          85     Non-veg      F     True   True
# 9998   40         174          44     Non-veg      M    False   True
# 9999   20         163          82     Non-veg      F    False  False
#
#       Protein_min(g)  Protein_max(g)
# 0              139.2           174.0
# 1               61.2            76.5
# ...

# %%
file.iloc[:,1].values.reshape(1,10000)
# Out:
# array([[167, 153, 160, ..., 169, 174, 163]])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(['Veg','Non-veg'])
# Out:
# LabelEncoder()

# %%
file['Veg'] = le.transform(file.iloc[:,3].values)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(['F','M'])
# Out:
# LabelEncoder()

# %%
file['Gender_encode'] = le.transform(file.iloc[:,4].values)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(['False','True'])
# Out:
# LabelEncoder()

# %%
file['Workout_encode'] = le.transform(file.iloc[:,5].values)
file['Vegan_encode'] = le.transform(file.iloc[:,6].values)

# %%
file
# Out:
#       Age  Height(cm)  Weight(kg) Veg/Non-Veg Gender  Workout  Vegan  \
# 0      33         167         116         Veg      F     True   True
# 1      42         153          51     Non-veg      F    False  False
# 2      26         160          44         Veg      F    False   True
# 3      38         155         108         Veg      F     True  False
# 4      18         162         106     Non-veg      M     True  False
# ...   ...         ...         ...         ...    ...      ...    ...
# 9995   45         168          97     Non-veg      M     True  False
# 9996   46         170         115         Veg      M     True   True
# 9997   22         169          85     Non-veg      F     True   True
# 9998   40         174          44     Non-veg      M    False   True
# 9999   20         163          82     Non-veg      F    False  False
#
#       Protein_min(g)  Protein_max(g)  Veg  Gender_encode  Workout_encode  \
# ...

# %%
X = file.drop(['Veg/Non-Veg','Gender','Workout','Vegan','Protein_min(g)','Protein_max(g)'],axis=1)
X
# Out:
#       Age  Height(cm)  Weight(kg)  Veg  Gender_encode  Workout_encode  \
# 0      33         167         116    1              0               1
# 1      42         153          51    0              0               0
# 2      26         160          44    1              0               0
# 3      38         155         108    1              0               1
# 4      18         162         106    0              1               1
# ...   ...         ...         ...  ...            ...             ...
# 9995   45         168          97    0              1               1
# 9996   46         170         115    1              1               1
# 9997   22         169          85    0              0               1
# 9998   40         174          44    0              1               0
# 9999   20         163          82    0              0               0
#
#       Vegan_encode
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ...

# %%
Y = file.iloc[:,7:9]
Y
# Out:
#       Protein_min(g)  Protein_max(g)
# 0              139.2           174.0
# 1               61.2            76.5
# 2               52.8            66.0
# 3              129.6           162.0
# 4              159.0           190.8
# ...              ...             ...
# 9995           145.5           174.6
# 9996           172.5           207.0
# 9997           102.0           127.5
# 9998            66.0            79.2
# 9999            98.4           123.0
#
# [10000 rows x 2 columns]

# %%
import xgboost as xgb
model = xgb.XGBRegressor()

# %%
model.fit(X.values, Y.values)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.predict([[42,153,	51,	0,	0,	0,	0]])
# Out:
# array([[61.19999 , 76.501144]], dtype=float32)
